# %%
# !pip install ai4bharat-transliteration
# Out:
# Collecting ai4bharat-transliteration
#   Downloading ai4bharat_transliteration-1.1.3-py3-none-any.whl (32 kB)
# Collecting sacremoses
#   Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 21.4 MB/s eta 0:00:00a 0:00:01
# Collecting tqdm
#   Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 26.7 MB/s eta 0:00:00
# Collecting ujson
#   Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 19.8 MB/s eta 0:00:00
# Collecting urduhack
#   Downloading urduhack-1.1.1-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.5/105.5 kB 35.6 MB/s eta 0:00:00
# Collecting flask
#   Downloading flask-3.0.3-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 39.5 MB/s eta 0:00:00
# Collecting fairseq
#   Using cached fairseq-0.12.2-cp310-cp310-linux_x86_64.whl
# Requirement already satisfied: pandas in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from ai4bharat-transliteration) (2.2.3)
# Collecting indic-nlp-library
#   Downloading indic_nlp_library-0.92-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 13.1 MB/s eta 0:00:00
# Collecting pydload
#   Downloading pydload-1.0.9-py2.py3-none-any.whl (16 kB)
# Collecting gevent
#   Downloading gevent-24.2.1-cp310-cp310-manylinux_2_28_x86_64.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 15.7 MB/s eta 0:00:00a 0:00:01
# Collecting pyarrow
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 11.1 MB/s eta 0:00:0000:0100:01
# Collecting tensorboardX
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 17.0 MB/s eta 0:00:00
# Collecting mock
#   Downloading mock-5.1.0-py3-none-any.whl (30 kB)
# Collecting flask-cors
#   Downloading Flask_Cors-5.0.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: torch in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from fairseq->ai4bharat-transliteration) (2.4.1)
# Collecting cython
#   Downloading Cython-3.0.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 20.8 MB/s eta 0:00:0000:0100:01
# Collecting cffi
#   Downloading cffi-1.17.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (446 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 446.2/446.2 kB 30.1 MB/s eta 0:00:00
# Collecting torchaudio>=0.8.0
#   Downloading torchaudio-2.4.1-cp310-cp310-manylinux1_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 19.3 MB/s eta 0:00:0000:0100:01
# Collecting bitarray
#   Downloading bitarray-2.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.3/288.3 kB 14.9 MB/s eta 0:00:00
# Collecting hydra-core<1.1,>=1.0.7
#   Downloading hydra_core-1.0.7-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 37.7 MB/s eta 0:00:00
# Collecting omegaconf<2.1
#   Downloading omegaconf-2.0.6-py3-none-any.whl (36 kB)
# Collecting regex
#   Downloading regex-2024.9.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (782 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 782.7/782.7 kB 76.1 MB/s eta 0:00:00
# Collecting sacrebleu>=1.4.12
#   Downloading sacrebleu-2.4.3-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 37.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from fairseq->ai4bharat-transliteration) (1.26.4)
# Requirement already satisfied: Werkzeug>=3.0.0 in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from flask->ai4bharat-transliteration) (3.0.4)
# Requirement already satisfied: Jinja2>=3.1.2 in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from flask->ai4bharat-transliteration) (3.1.4)
# Collecting itsdangerous>=2.1.2
#   Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Collecting blinker>=1.6.2
#   Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Collecting click>=8.1.3
#   Downloading click-8.1.7-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 37.6 MB/s eta 0:00:00
# Collecting zope.event
#   Downloading zope.event-5.0-py3-none-any.whl (6.8 kB)
# Collecting zope.interface
#   Downloading zope.interface-7.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (254 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 72.4 MB/s eta 0:00:00
# Collecting greenlet>=2.0.0
#   Downloading greenlet-3.1.1-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (599 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.5/599.5 kB 46.3 MB/s eta 0:00:00
# Collecting morfessor
#   Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Collecting sphinx-rtd-theme
#   Downloading sphinx_rtd_theme-3.0.1-py2.py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 9.3 MB/s eta 0:00:0000:0100:01m
# Collecting sphinx-argparse
#   Downloading sphinx_argparse-0.5.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/skywalker/.local/lib/python3.10/site-packages (from pandas->ai4bharat-transliteration) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pandas->ai4bharat-transliteration) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pandas->ai4bharat-transliteration) (2024.2)
# Collecting progressbar2
#   Downloading progressbar2-4.5.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 19.2 MB/s eta 0:00:00
# Requirement already satisfied: requests in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from pydload->ai4bharat-transliteration) (2.32.3)
# Collecting joblib
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 36.6 MB/s eta 0:00:00
# Requirement already satisfied: protobuf>=3.20 in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from tensorboardX->ai4bharat-transliteration) (4.25.5)
# Requirement already satisfied: packaging in /home/skywalker/.local/lib/python3.10/site-packages (from tensorboardX->ai4bharat-transliteration) (24.1)
# Collecting tensorflow-datasets~=3.1
#   Downloading tensorflow_datasets-3.2.1-py3-none-any.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 17.8 MB/s eta 0:00:00a 0:00:01
# Collecting urduhack
#   Downloading urduhack-1.1.0-py3-none-any.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 14.5 MB/s eta 0:00:00
#   Downloading urduhack-1.0.3-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.0/98.0 kB 30.1 MB/s eta 0:00:00
#   Downloading urduhack-1.0.2-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 35.9 MB/s eta 0:00:00
#   Downloading urduhack-1.0.1-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.7/96.7 kB 34.9 MB/s eta 0:00:00
#   Downloading urduhack-1.0.0-py3-none-any.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.5/99.5 kB 34.9 MB/s eta 0:00:00
#   Downloading urduhack-0.3.4-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 24.1 MB/s eta 0:00:00
# Collecting pyconll~=2.2
#   Downloading pyconll-2.3.3-py3-none-any.whl (23 kB)
# Collecting transformers~=2.10
#   Downloading transformers-2.11.0-py3-none-any.whl (674 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 674.8/674.8 kB 48.0 MB/s eta 0:00:00
# Collecting urduhack
#   Downloading urduhack-0.3.3-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.3/82.3 kB 19.8 MB/s eta 0:00:00
#   Downloading urduhack-0.3.2-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.6/81.6 kB 31.5 MB/s eta 0:00:00
#   Downloading urduhack-0.3.1-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 27.6 MB/s eta 0:00:00
#   Downloading urduhack-0.2.7-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.3/75.3 kB 9.3 MB/s eta 0:00:00
#   Downloading urduhack-0.2.6-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.3/75.3 kB 25.5 MB/s eta 0:00:00
#   Downloading urduhack-0.2.5-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.3/71.3 kB 27.0 MB/s eta 0:00:00
#   Downloading urduhack-0.2.4-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.3/71.3 kB 23.9 MB/s eta 0:00:00
#   Downloading urduhack-0.2.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.2/71.2 kB 25.9 MB/s eta 0:00:00
#   Downloading urduhack-0.2.2-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 22.9 MB/s eta 0:00:00
#   Downloading urduhack-0.2.1-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.0/66.0 kB 21.0 MB/s eta 0:00:00
#   Downloading urduhack-0.1.4-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.9/62.9 kB 23.5 MB/s eta 0:00:00
# Collecting antlr4-python3-runtime==4.8
#   Downloading antlr4-python3-runtime-4.8.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 42.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: MarkupSafe>=2.0 in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from Jinja2>=3.1.2->flask->ai4bharat-transliteration) (2.1.5)
# Requirement already satisfied: typing-extensions in /home/skywalker/.local/lib/python3.10/site-packages (from omegaconf<2.1->fairseq->ai4bharat-transliteration) (4.12.2)
# Collecting PyYAML>=5.1.*
#   Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.2/751.2 kB 56.4 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /home/skywalker/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->ai4bharat-transliteration) (1.16.0)
# Collecting tabulate>=0.8.9
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting lxml
#   Downloading lxml-5.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 16.6 MB/s eta 0:00:00a 0:00:01
# Collecting portalocker
#   Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from torch->fairseq->ai4bharat-transliteration) (11.4.5.107)
# Requirement already satisfied: sympy in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from torch->fairseq->ai4bharat-transliteration) (1.13.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from torch->fairseq->ai4bharat-transliteration) (2.20.5)
# Requirement already satisfied: triton==3.0.0 in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from torch->fairseq->ai4bharat-transliteration) (3.0.0)
# Requirement already satisfied: filelock in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from torch->fairseq->ai4bharat-transliteration) (3.16.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from torch->fairseq->ai4bharat-transliteration) (11.0.2.54)
# Requirement already satisfied: fsspec in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from torch->fairseq->ai4bharat-transliteration) (2024.9.0)
# Requirement already satisfied: networkx in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from torch->fairseq->ai4bharat-transliteration) (3.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from torch->fairseq->ai4bharat-transliteration) (12.1.105)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from torch->fairseq->ai4bharat-transliteration) (12.1.0.106)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from torch->fairseq->ai4bharat-transliteration) (10.3.2.106)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from torch->fairseq->ai4bharat-transliteration) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from torch->fairseq->ai4bharat-transliteration) (9.1.0.70)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from torch->fairseq->ai4bharat-transliteration) (12.1.105)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from torch->fairseq->ai4bharat-transliteration) (12.1.3.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from torch->fairseq->ai4bharat-transliteration) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->fairseq->ai4bharat-transliteration) (12.6.68)
# Collecting pycparser
#   Downloading pycparser-2.22-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.6/117.6 kB 19.9 MB/s eta 0:00:00
# Collecting python-utils>=3.8.1
#   Downloading python_utils-3.9.0-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from requests->pydload->ai4bharat-transliteration) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from requests->pydload->ai4bharat-transliteration) (2.2.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from requests->pydload->ai4bharat-transliteration) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from requests->pydload->ai4bharat-transliteration) (2024.8.30)
# Collecting docutils>=0.19
#   Downloading docutils-0.21.2-py3-none-any.whl (587 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.4/587.4 kB 39.6 MB/s eta 0:00:00
# Collecting sphinx>=5.1.0
#   Downloading sphinx-8.0.2-py3-none-any.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 20.9 MB/s eta 0:00:00a 0:00:01
# Collecting sphinxcontrib-jquery<5,>=4
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from zope.event->gevent->ai4bharat-transliteration) (65.5.0)
# Collecting tomli>=2
#   Downloading tomli-2.0.2-py3-none-any.whl (13 kB)
# Collecting sphinxcontrib-htmlhelp>=2.0.0
#   Downloading sphinxcontrib_htmlhelp-2.1.0-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 31.7 MB/s eta 0:00:00
# Collecting snowballstemmer>=2.2
#   Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.0/93.0 kB 27.4 MB/s eta 0:00:00
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-2.0.0-py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.7/88.7 kB 30.6 MB/s eta 0:00:00
# Collecting alabaster>=0.7.14
#   Downloading alabaster-1.0.0-py3-none-any.whl (13 kB)
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-2.0.0-py3-none-any.whl (119 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.3/119.3 kB 44.3 MB/s eta 0:00:00
# Collecting sphinxcontrib-serializinghtml>=1.1.9
#   Downloading sphinxcontrib_serializinghtml-2.0.0-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 35.8 MB/s eta 0:00:00
# Requirement already satisfied: Pygments>=2.17 in /home/skywalker/.local/lib/python3.10/site-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library->ai4bharat-transliteration) (2.18.0)
# Collecting babel>=2.13
#   Downloading babel-2.16.0-py3-none-any.whl (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 13.7 MB/s eta 0:00:0000:0100:01
# Collecting imagesize>=1.3
#   Downloading imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-2.0.0-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.5/82.5 kB 17.2 MB/s eta 0:00:00
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/skywalker/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from sympy->torch->fairseq->ai4bharat-transliteration) (1.3.0)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141212 sha256=8e8aacd016cce4cc1ed89521f582d64b425dc07e9e5ed03439e54c015b3af630
#   Stored in directory: /home/skywalker/.cache/pip/wheels/a7/20/bd/e1477d664f22d99989fd28ee1a43d6633dddb5cb9e801350d5
# Successfully built antlr4-python3-runtime
# Installing collected packages: snowballstemmer, morfessor, bitarray, antlr4-python3-runtime, zope.interface, zope.event, ujson, tqdm, tomli, tensorboardX, tabulate, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, regex, PyYAML, python-utils, pycparser, pyarrow, portalocker, mock, lxml, joblib, itsdangerous, imagesize, greenlet, docutils, cython, colorama, click, blinker, babel, alabaster, urduhack, sphinx, sacremoses, sacrebleu, progressbar2, omegaconf, gevent, flask, cffi, sphinxcontrib-jquery, sphinx-argparse, pydload, hydra-core, flask-cors, torchaudio, sphinx-rtd-theme, indic-nlp-library, fairseq, ai4bharat-transliteration
# Successfully installed PyYAML-6.0.2 ai4bharat-transliteration-1.1.3 alabaster-1.0.0 antlr4-python3-runtime-4.8 babel-2.16.0 bitarray-2.9.2 blinker-1.8.2 cffi-1.17.1 click-8.1.7 colorama-0.4.6 cython-3.0.11 docutils-0.21.2 fairseq-0.12.2 flask-3.0.3 flask-cors-5.0.0 gevent-24.2.1 greenlet-3.1.1 hydra-core-1.0.7 imagesize-1.4.1 indic-nlp-library-0.92 itsdangerous-2.2.0 joblib-1.4.2 lxml-5.3.0 mock-5.1.0 morfessor-2.0.6 omegaconf-2.0.6 portalocker-2.10.1 progressbar2-4.5.0 pyarrow-17.0.0 pycparser-2.22 pydload-1.0.9 python-utils-3.9.0 regex-2024.9.11 sacrebleu-2.4.3 sacremoses-0.1.1 snowballstemmer-2.2.0 sphinx-8.0.2 sphinx-argparse-0.5.2 sphinx-rtd-theme-3.0.1 sphinxcontrib-applehelp-2.0.0 sphinxcontrib-devhelp-2.0.0 sphinxcontrib-htmlhelp-2.1.0 sphinxcontrib-jquery-4.1 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-2.0.0 sphinxcontrib-serializinghtml-2.0.0 tabulate-0.9.0 tensorboardX-2.6.2.2 tomli-2.0.2 torchaudio-2.4.1 tqdm-4.66.5 ujson-5.10.0 urduhack-0.1.4 zope.event-5.0 zope.interface-7.0.3
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
from ai4bharat.transliteration import XlitEngine
# intializing the en-indic multilingual model and dictionaries (if rerank option is True)
e = XlitEngine("hi", beam_width=4, rescore=True, src_script_type = "en")

# transliterate word
# Out:
# Initializing Multilingual model for transliteration
# Loading dicts into RAM: 100%|██████████| 1/1 [00:02<00:00,  2.83s/it]

# %%
out = e.translit_word("101 special", topk=1)
print(out)
# Out:
# {'hi': ['101 स्पेशियल']}
